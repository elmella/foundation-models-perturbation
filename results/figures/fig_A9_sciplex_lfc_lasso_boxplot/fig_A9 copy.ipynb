# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import json
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib as mpl

# %% [markdown]
# ## Settings

# %%
lasso_or_knn = "lasso" # knn, lasso

# %% [markdown]
# ## Load scores and plotting metadata

# %%
repo_root = next(
    p for p in [Path.cwd(), *Path.cwd().parents]
    if (p / "results" / "scores" / "sciplex_lfc_restricted.csv").exists()
)
df = pd.read_csv(repo_root / "results" / "scores" / "sciplex_lfc_restricted.csv", index_col=0)

# %%
with open(repo_root / "results" / "metadata" / "fig_index.json", "r") as f:
    fig_index = json.load(f)

method_map = {
    k.replace("HEAD_TYPE", lasso_or_knn): v
    for k, v in fig_index["sciplex_lfc"].items()
}
method_map.update({
    f"{lasso_or_knn}_baseline_LPM_emb": ["LPM", "Response Embedding"],
    f"{lasso_or_knn}_baseline_ECFP:2_pkl": ["ECFP:2", "Molecule Structure"],
    f"{lasso_or_knn}_baseline_cats2D": ["CATS2D", "Molecule Structure"],
    f"{lasso_or_knn}_baseline_cats3D": ["CATS3D", "Molecule Structure"],
    f"{lasso_or_knn}_baseline_fcfp": ["FCFP", "Molecule Structure"],
})
model_type_palette = fig_index['drugs_model_type_palette']
model_type_palette["Response Embedding"] = "#8CD17DFF"
hue_order = fig_index['drugs_hue_order']
hue_order = [*hue_order, "Response Embedding"]
mpl.rcParams.update(fig_index["mpl_params"])

# %% [markdown]
# ## Split by cell line

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6), constrained_layout=True)
for i, cell_line in enumerate(['MCF7', 'K562', 'A549']):

    # Build the cell-line specific dataframe
    idx = (df["fold"].str.contains(cell_line)) & df["name"].isin(method_map)
    df_subset = df[idx].copy()
    df_subset["Model type"] = df_subset["name"].apply(lambda x: method_map[x][1])
    df_subset["name"] = df_subset["name"].apply(lambda x: method_map[x][0])

    present_hues = [
        h for h in hue_order
        if h in df_subset["Model type"].unique()
    ]
    
    # Boxplot
    g = sns.boxplot(
        data=df_subset,
        y="name",
        order=[name for name, _ in method_map.values()],
        hue="Model type",
        hue_order=present_hues,
        x="L2",
        ax=axes[i],
        whis=(0, 100),
        width=0.65,
        palette=model_type_palette,
    )

    # Overlay stripplot
    sns.stripplot(
        data=df_subset,
        y="name",
        order=[name for name, _ in method_map.values()],
        color="black",
        alpha=0.5,
        s=5,
        x="L2",
        ax=axes[i],
    )

    # Decorate
    g.grid(axis="y")
    g.set(ylabel=None, title=cell_line)
    g.set_xlabel('L2')
    g.legend(title=None)
    if i > 0:
        g.set(yticklabels=[])
        g.legend().remove()

    # Get the best performing model
    best_mask = (
        (df_subset["Model type"] != "Positive Control") &
        (df_subset["Model type"] != "Fusion")
    )
    best_group = (
        df_subset.loc[best_mask]
        .groupby("name")["L2"]
        .median()
    )
    best_name = best_group.idxmin()
    best_level = best_group.loc[best_name]
    best_model_type = (
        df_subset.loc[df_subset["name"] == best_name, "Model type"]
        .iloc[0]
    )

    # Draw vertical lines
    g.axvline(
        df_subset[df_subset["name"] == "Train Mean"]["L2"].median(),
        color=model_type_palette["Negative Control"],
        linestyle="--",
        linewidth=1,
        zorder=99,
        alpha=0.75,
    )
    g.axvline(
        df_subset[
            df_subset["name"] == f"Experimental Error"
        ]["L2"].median(),
        color=model_type_palette["Positive Control"],
        linestyle="--",
        linewidth=1,
        zorder=-99,
        alpha=0.75,
    )
    g.axvline(
        best_level,
        color=model_type_palette[best_model_type],
        linestyle="--",
        linewidth=1,
        zorder=99,
        alpha=0.75,
    )
plt.savefig(f"fig_A9_restricted.pdf")
